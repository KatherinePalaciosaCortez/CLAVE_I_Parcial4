# %% [markdown]
# <a href="https://colab.research.google.com/github/KatherinePalaciosaCortez/CLAVE_I_Parcial4/blob/main/notebooks/correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# 1. Cargar archivo
df = pd.read_csv("Ehttps://raw.githubusercontent.com/KatherinePalaciosaCortez/CLAVE_I_Parcial4/refs/heads/main/data/raw/clave_I_correlacion.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_49010/783739023.py in <cell line: 0>()
#       3
#       4 # 1. Cargar archivo
# ----> 5 df = pd.read_csv("Ehttps://raw.githubusercontent.com/KatherinePalaciosaCortez/CLAVE_I_Parcial4/refs/heads/main/data/raw/clave_I_correlacion.csv")
#       6
#       7
#
# ...

# %%
# 2. Revision inicial
print("Dimensiones del dataset:")
print(df.shape)

print("
Primeras filas:")
print(df.head())

print("
Informacion general:")
