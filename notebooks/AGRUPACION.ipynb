# %% [markdown]
# <a href="https://colab.research.google.com/github/KatherinePalaciosaCortez/CLAVE_I_Parcial4/blob/main/notebooks/AGRUPACION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# VALIDACION INICAL

# %%
#  Cargar el archivo CSV

import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/KatherinePalaciosaCortez/CLAVE_I_Parcial4/refs/heads/main/data/raw/clave_I_agrupacion.csv")

# %%
#Valores nulos
print("\nValores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# registro_id         0
# edad                0
# ingresos            0
# frecuencia_uso      0
# gasto_promedio      0
# satisfaccion        1
# reclamos            0
# antiguedad_meses    0
# dtype: int64

# %%
#valores duplicados
print("\nCantidad de registros duplicados:")
print(df.duplicated().sum())
# Out:
# Cantidad de registros duplicados:
# 0

# %%
# tipos de datos
print("\nInformación general del dataset:")
print(df.info())
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   registro_id       262 non-null    object
#  1   edad              262 non-null    int64
#  2   ingresos          262 non-null    int64
#  3   frecuencia_uso    262 non-null    float64
#  4   gasto_promedio    262 non-null    float64
#  5   satisfaccion      261 non-null    float64
#  6   reclamos          262 non-null    int64
#  7   antiguedad_meses  262 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.5+ KB
# None

# %%
#  Validamos las dimensiones del dataset
print("Dimensiones del dataset:")
print(df.shape)
# Out:
# Dimensiones del dataset:
# (262, 8)

# %%
#  Revisamos las columnas disponibles
print("\nColumnas del dataset:")
print(df.columns)
# Out:
# Columnas del dataset:
# Index(['registro_id', 'edad', 'ingresos', 'frecuencia_uso', 'gasto_promedio',
#        'satisfaccion', 'reclamos', 'antiguedad_meses'],
#       dtype='object')

# %%
# Mostrar las primeras filas
print("\nPrimeras filas del dataset:")
print(df.head())
# Out:
# Primeras filas del dataset:
#   registro_id  edad  ingresos  frecuencia_uso  gasto_promedio  satisfaccion  \
# 0     I-R0155    41      1855            8.60          192.15          8.53
# 1     I-R0116    33       994            6.04           62.84          9.40
# 2     I-R0233    43       807            2.94           73.22          4.81
# 3     I-R0167    52      1528            9.44          157.53          7.15
# 4     I-R0108    27      1169            6.04           92.08          7.97
#
#    reclamos  antiguedad_meses
# 0         1                52
# 1         1                18
# 2         3                12
# 3        12                54
# 4         1                 7

# %%
#valores atipicos

variables_numericas = ["ingresos", "edad"]

print("\nRevisión de valores atípicos:")
for columna in variables_numericas:
    media = df[columna].mean()
    desviacion = df[columna].std()

    limite_inferior = media - 2 * desviacion
    limite_superior = media + 2 * desviacion

    outliers = df[
        (df[columna] < limite_inferior) |
        (df[columna] > limite_superior)
    ]

    print("Variable:", columna)
    print("Media:", round(media, 2))
    print("Desviación estándar:", round(desviacion, 2))
    print("Límite inferior:", round(limite_inferior, 2))
    print("Límite superior:", round(limite_superior, 2))
    print("Cantidad de valores atípicos:", len(outliers))
    print("-" * 40)
# Out:
# Revisión de valores atípicos:
# Variable: ingresos
# Media: 1155.77
# Desviación estándar: 444.73
# Límite inferior: 266.3
# Límite superior: 2045.24
# Cantidad de valores atípicos: 7
# ----------------------------------------
# Variable: edad
# Media: 41.84
# Desviación estándar: 9.96
# Límite inferior: 21.93
# Límite superior: 61.76
# Cantidad de valores atípicos: 8
# ----------------------------------------

# %%
# 10. Revisión de variables categóricas
print("\nDistribución de reclamos:")
print(df["reclamos"].value_counts())


print("\nDistribución de satisfacion:")
print(df["satisfaccion"].value_counts())
# Out:
# Distribución de reclamos:
# reclamos
# 2     48
# 1     47
# 0     47
# 4     40
# 3     39
# 5     21
# 6     12
# 7      7
# 12     1
# Name: count, dtype: int64
#
# Distribución de satisfacion:
# satisfaccion
# 10.00    6
# 8.02     3
# 7.97     3
# 8.01     3
# 4.08     2
#         ..
# 8.50     1
# 7.08     1
# 9.21     1
# 2.93     1
# 7.48     1
# Name: count, Length: 219, dtype: int64

# %%
# Selección de columnas para reglas de asociación
columnas_asociacion = [
    "reclamos",
    "satisfaccion",


]

df_asociacion = df[columnas_asociacion].copy()

print("\nPrimeras filas del dataset de asociación:")
print(df_asociacion.head())
# Out:
# Primeras filas del dataset de asociación:
#    reclamos  satisfaccion
# 0         1          8.53
# 1         1          9.40
# 2         3          4.81
# 3        12          7.15
# 4         1          7.97

# %%
# 12. Validación de valores binarios
print("\nValores únicos en columnas de asociación:")
for columna in columnas_asociacion:
    print(columna, df_asociacion[columna].unique())
# Out:
# Valores únicos en columnas de asociación:
# reclamos [ 1  3 12  0  4  2  7  5  6]
# satisfaccion [ 8.53  9.4   4.81  7.15  7.97  8.39  9.35  4.93  8.58  3.44  4.67  4.35
#   8.77  8.21  9.6   4.24  8.05  6.55  8.96  8.13  3.39  9.11   nan  6.08
#   4.46  6.51  4.08  8.02  7.93  5.57  4.05  5.16  8.98  9.23  3.65  7.28
#   8.78  8.69  7.05  7.55  8.59  8.22  9.64  8.61 10.    7.95  3.62  6.62
#   3.66  5.    7.82  7.85  3.38  6.63  7.02  4.48  5.31  7.94  5.03  8.66
#   7.65  4.76  8.01  7.56  7.96  5.61  4.28  5.26  8.    6.13  9.27  5.27
#   8.89  6.39  8.56  9.33  9.09  9.36  6.19  6.41  9.79  6.64  4.19  7.98
#   3.45  5.49  3.28  4.61  7.67  9.04  9.28  4.74  5.63  7.11  7.54  5.23
#   6.04  6.21  8.41  7.57  6.97  8.99  7.34  9.44  8.15  7.92  5.96  4.99
#   5.98  4.7   9.81  7.81  4.25  7.06  8.82  9.08  6.09  9.02  7.76  7.27
#   5.75  7.24  4.12  5.19  5.69  6.48  7.59  9.15  6.99  6.18  5.06  9.48
#   7.75  6.75  6.84  7.52  8.52  6.1   8.1   8.97  6.54  5.92  6.49  8.8
#   5.76  6.67  6.2   4.69  9.13  7.83  9.59  6.43  8.83  8.17  4.57  8.95
#   4.85  5.43  2.77  4.64  9.07  8.14  7.69  5.44  6.93  9.99  6.7   6.34
#   6.92  6.31  7.63  4.32  7.41  6.23  9.74  7.33  9.24  7.26  9.22  9.34
#   8.55  6.11  9.88  7.9   8.43  9.05  4.82  7.77  6.    5.82  6.73  6.71
#   4.39  9.32  5.45  3.98  5.38  6.14  8.24  6.6   9.54  8.92  7.91  9.7
#   7.35  4.17  8.64  9.3   4.58  5.72  5.97  7.88  4.18  3.3   9.14  8.5
#   7.08  9.21  2.93  7.48]

# %%
# 13. Conversión de 0/1 a booleanos
df_asociacion_bool = df_asociacion.astype(bool)

print("\nTipos de datos después de convertir a booleanos:")
print(df_asociacion_bool.dtypes)

print("\nPrimeras filas del dataset booleano:")
print(df_asociacion_bool.head())
# Out:
# Tipos de datos después de convertir a booleanos:
# reclamos        bool
# satisfaccion    bool
# dtype: object
#
# Primeras filas del dataset booleano:
#    reclamos  satisfaccion
# 0      True          True
# 1      True          True
# 2      True          True
# 3      True          True
# 4      True          True

# %%
print(df_asociacion_bool.head())
# Out:
#    reclamos  satisfaccion
# 0      True          True
# 1      True          True
# 2      True          True
# 3      True          True
# 4      True          True
